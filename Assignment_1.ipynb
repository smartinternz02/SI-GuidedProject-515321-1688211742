# %%
import pandas as pd
import numpy as np

# %%
#Create a dataframe with 4 features and 4 observation
s1= pd.Series(np.random.rand(4))
s2= pd.Series(np.random.rand(4))
s3= pd.Series(np.random.rand(4))
s4= pd.Series(np.random.rand(4))
df=pd.DataFrame([s1,s2,s3,s4])
df
# Out:
#           0         1         2         3
# 0  0.476414  0.853014  0.543468  0.083120
# 1  0.010980  0.132368  0.925221  0.203373
# 2  0.660059  0.755466  0.414949  0.125542
# 3  0.101963  0.048377  0.457797  0.578749

# %%
#Change column names
df.columns = ['Random value 1', 'Random value 2', 'Random value 3', 'Random value 4']
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0        0.476414        0.853014        0.543468        0.083120
# 1        0.010980        0.132368        0.925221        0.203373
# 2        0.660059        0.755466        0.414949        0.125542
# 3        0.101963        0.048377        0.457797        0.578749

# %%
#Descriptive statistics
df.describe()
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.312354        0.447306        0.585359        0.247696
# std          0.307086        0.415488        0.232789        0.226250
# min          0.010980        0.048377        0.414949        0.083120
# 25%          0.079217        0.111370        0.447085        0.114937
# 50%          0.289188        0.443917        0.500633        0.164458
# 75%          0.522325        0.779853        0.638906        0.297217
# max          0.660059        0.853014        0.925221        0.578749

# %%
#Check for the null values
df.isnull().sum()
# Out:
# Random value 1    0
# Random value 2    0
# Random value 3    0
# Random value 4    0
# dtype: int64

# %%
#Data type of the columns
print(df['Random value 1'].dtype)
print(df['Random value 2'].dtype)
print(df['Random value 3'].dtype)
print(df['Random value 4'].dtype)
# Out:
# float64
# float64
# float64
# float64

# %%
#Display 'Random value 2' & 'Random value 3' columns with location method
loc = df.loc[:, ['Random value 2', 'Random value 3']]
print(loc)
# Out:
#    Random value 2  Random value 3
# 0        0.853014        0.543468
# 1        0.132368        0.925221
# 2        0.755466        0.414949
# 3        0.048377        0.457797

# %%
#Display the 'Random value 2' & 'Random value 3' columns with index location method
iloc = df.iloc[:, [1, 2]]
print(iloc)
# Out:
#    Random value 2  Random value 3
# 0        0.853014        0.543468
# 1        0.132368        0.925221
# 2        0.755466        0.414949
# 3        0.048377        0.457797
